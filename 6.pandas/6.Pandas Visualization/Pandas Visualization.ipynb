# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"E:\powerBI\6.pandas\6.Pandas Visualization\Ice Cream Ratings.csv")
df = df.set_index('Date')
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %% [markdown]
# # LINE PLOT

# %%
df.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df.plot(kind = 'line', subplots = True, title = 'ICe Cream Rating', xlabel = 'Daily Ratings', ylabel = 'Score')
# Out:
# array([<AxesSubplot: xlabel='Daily Ratings', ylabel='Score'>,
#        <AxesSubplot: xlabel='Daily Ratings', ylabel='Score'>,
#        <AxesSubplot: xlabel='Daily Ratings', ylabel='Score'>],
#       dtype=object)

# %% [markdown]
# # Bar Graph

# %%
df.plot(kind = 'bar')
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df.plot(kind = 'bar', stacked = True)
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
#for one column only
df['Flavor Rating'].plot(kind = 'bar', stacked = True)
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
#horizontal bar chart
df.plot.barh(stacked = True)
# Out:
# <AxesSubplot: ylabel='Date'>

# %% [markdown]
# # Scatter plot

# %%
# s = dot size, c = color
df.plot.scatter(x = 'Texture Rating', y = 'Overall Rating', s = 500, c = 'Green')
# Out:
# <AxesSubplot: xlabel='Texture Rating', ylabel='Overall Rating'>

# %% [markdown]
# # histagram

# %%
df.plot.hist(bins = 10)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df.plot.hist(bins = 20)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# # box plot

# %%
df.boxplot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# # area plot

# %%
df.plot.area(figsize = (10,5))
# Out:
# <AxesSubplot: xlabel='Date'>

# %% [markdown]
# # pie chart

# %%
df.plot.pie(y='Flavor Rating',figsize=(10,10))
# Out:
# <AxesSubplot: ylabel='Flavor Rating'>
